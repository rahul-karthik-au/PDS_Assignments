# %%
import numpy as np
import pandas as pd

student_data=pd.read_csv('StudentsPerformance.csv')
student_data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
student_data.drop('lunch', axis=1, inplace=True)

csv_filename = 'clean_student_data.csv'
df = pd.DataFrame(student_data)
df.to_csv(csv_filename, index=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt

race_counts = student_data['race/ethnicity'].value_counts()

plt.figure(figsize=(6, 6))
plt.pie(race_counts, labels=race_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Race/Ethnicity')
plt.axis('equal')
plt.show()

# %%
parental_level_of_education_count = student_data['parental level of education'].value_counts()

plt.figure(figsize=(6, 6))
plt.pie(parental_level_of_education_count, labels=parental_level_of_education_count.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Parental Level Of Education')
plt.axis('equal')
plt.show()

# %%
import seaborn as sns

avg_math_scores = student_data.groupby(['race/ethnicity', 'gender'])['math score'].mean().unstack()

plt.figure(figsize=(10, 6))
avg_math_scores.plot(kind='bar',color=sns.palettes.mpl_palette('Dark2'),  alpha=0.7)
plt.title('Average Math Scores by Gender and Race/Ethnicity')
plt.xlabel('Race/Ethnicity')
plt.ylabel('Average Math Score')

plt.legend(title='Gender')

plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
avg_reading_scores = student_data.groupby(['race/ethnicity', 'gender'])['reading score'].mean().unstack()

plt.figure(figsize=(10, 6))

avg_reading_scores.plot(kind='bar', color=['blue', 'orange'], alpha=0.7)

plt.title('Average Reading Scores by Gender and Race/Ethnicity')

plt.xlabel('Race/Ethnicity')
plt.ylabel('Average Reading Score')

plt.legend(title='Gender')

plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
avg_writing_scores = student_data.groupby(['race/ethnicity', 'gender'])['writing score'].mean().unstack()

plt.figure(figsize=(10, 6))

avg_reading_scores.plot(kind='bar', alpha=0.7)

plt.title('Average Reading Scores by Gender and Race/Ethnicity')

plt.xlabel('Race/Ethnicity')
plt.ylabel('Average Reading Score')

plt.legend(title='Gender')

plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
above_80_math_count = student_data[student_data['math score'] > 80].groupby(['test preparation course','race/ethnicity'])['math score'].size().unstack()

plt.figure(figsize=(20, 6))
above_80_math_count.plot(kind='bar')
plt.title('Count of Math Scores Above 80 by Test Preparation Course and Race/Ethincity')
plt.xlabel('Test Preparation Course')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
above_80_reading_count = student_data[student_data['reading score'] > 80].groupby(['test preparation course','race/ethnicity'])['reading score'].size().unstack()

plt.figure(figsize=(20, 6))
above_80_reading_count.plot(kind='bar')
plt.title('Count of Reading Scores Above 80 by Test Preparation Course and Race/Ethincity')
plt.xlabel('Test Preparation Course')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
above_80_writing_count = student_data[student_data['writing score'] > 80].groupby(['test preparation course','race/ethnicity'])['writing score'].size().unstack()

plt.figure(figsize=(20, 6))
above_80_writing_count.plot(kind='bar')
plt.title('Count of Writing Scores Above 80 by Test Preparation Course and Race/Ethincity')
plt.xlabel('Test Preparation Course')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
above_80_math_count_1 = student_data[student_data['math score'] > 80].groupby(['test preparation course','gender'])['math score'].size().unstack()

plt.figure(figsize=(20, 6))
above_80_math_count_1.plot(kind='bar')
plt.title('Count of Math Scores Above 80 by Test Preparation Course and Gender')
plt.xlabel('Test Preparation Course')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
above_80_reading_count_1 = student_data[student_data['reading score'] > 80].groupby(['test preparation course','gender'])['reading score'].size().unstack()

plt.figure(figsize=(20, 6))
above_80_reading_count_1.plot(kind='bar')
plt.title('Count of Reading Scores Above 80 by Test Preparation Course and Gender')
plt.xlabel('Test Preparation Course')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
above_80_writing_count_1 = student_data[student_data['writing score'] > 80].groupby(['test preparation course','gender'])['writing score'].size().unstack()

plt.figure(figsize=(20, 6))
above_80_writing_count_1.plot(kind='bar')
plt.title('Count of Writing Scores Above 80 by Test Preparation Course and Gender')
plt.xlabel('Test Preparation Course')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
below_50_none_df = student_data[(student_data['math score'] < 50) & (student_data['reading score'] < 50) & (student_data['writing score'] < 50)]
grouped_data = below_50_none_df.groupby('test preparation course').size().reset_index(name='count')

plt.figure(figsize=(8, 6))
sns.barplot(x='test preparation course', y='count', data=grouped_data)
plt.title('Count of Students with Scores Below 50 by Test Preparation Course')
plt.xlabel('Test Preparation Course')
plt.ylabel('Count')
plt.show()
